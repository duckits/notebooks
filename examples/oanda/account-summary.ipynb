# %%
import sys
sys.path.append('../../')
from fxtrade.broker.oanda import Oanda

# %%
client = Oanda()

# %%
print(client.get_account_summary())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 print(client.get_account_summary())
#
# File ~/examples/oanda/../../fxtrade/broker/oanda.py:37, in Oanda.get_account_summary(self)
#      36 def get_account_summary(self):
# ---> 37   data = self.request(f"accounts/{self.account_id}/summary")
#      38   print(data)
#      39   return data['account']
#
# File ~/examples/oanda/../../fxtrade/broker/oanda.py:21, in Oanda.request(self, url, verb, params, data, headers)
#      19 response = None
#      20 if verb == "get":
# ---> 21   response = self.session.get(full_url, params=params, data=data, headers=headers)
#      23 if response == None:
#      24   return False, {'error': 'verb not found'}
#
# File /opt/conda/lib/python3.10/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
# ...
